# %%
import requests
from urllib.parse import urlencode
from pyquery import PyQuery as pq
import time 
import random
import json

# %%
base_url = 'https://m.weibo.cn/api/container/getIndex?'
headers = {
    'Host': 'm.weibo.cn',
    'Referer': 'https://m.weibo.cn/search?containerid=100103type%3D1%26q%3D%E8%B4%B8%E6%98%93%E6%88%98',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_2) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/12.0.2 Safari/605.1.15',
    'X-Requested-With': 'XMLHttpRequest',
    'MWeibo-Pwa': '1'
}

# %%
max_page = 10

# %%
def get_page(page):
    params = {
        'containerid': '100103type=61&q=myz&t=0',
        'page_type': 'searchall',
        'page': page
    }
    url = base_url + urlencode(params)
    # print(url)
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return response.json(), page
    except requests.ConnectionError as e:
        print('Error', e.args)

# %%
def fix_date(orig):
    if u'前' in orig:
        return '07-29'
    elif u'昨天' in orig:
        return '07-28'
    elif u'前天' in orig:
        return '07-27'
    else:
        return orig

# %%
def parse_page(json_data, page: int):
    try:
        items = json_data.get('data').get('cards')[0].get('card_group')
    except:
        items = []
    for index, item in enumerate(items):
        item = item.get('mblog')
        weibo = {}
        weibo['id'] = item.get('id')
        weibo['created_at'] = fix_date(item.get('created_at'))
        weibo['text'] = pq(item.get('text')).text()
        weibo['attitudes'] = item.get('attitudes_count')
        weibo['comments'] = item.get('comments_count')
        weibo['reposts'] = item.get('reposts_count')
        try:
            weibo['origin_text'] = pq(item.get('retweeted_status').get('text')).text()
            weibo['origin_user'] = item.get('retweeted_status').get('user').get('screen_name')
            weibo['origin_created_at'] = fix_date(item.get('retweeted_status').get('created_at'))
        except:
            pass
        try:
            weibo['page_title'] = item.get('page_info').get('page_title')
            weibo['page_url'] = item.get('page_info').get('page_url')
        except:
            pass
        try:
            weibo['long_text'] = pq(item.get('longText').get('longTextContent')).text()
        except:
            pass
        yield weibo

# %%
def save_to_file(result):
    with open(result_path, 'ab') as f:
        f.write(json.dumps(result, ensure_ascii=False).encode('utf-8'))
        f.write('\r\n'.encode('utf-8'))

# %%
result_path = './data/keyword_raw_0729_3.json'

# %%
total = 0
for page in range(2,400):
    json_data = get_page(page)
    results = parse_page(*json_data)
    for result in results:
        save_to_file(result)
        total += 1
    if page % 5 == 0:
        print('Page %d done, total %d weibos'%(page, total))
    time.sleep(random.randint(2, 4))
# Out:
# Page 5 done, total 36 weibos
# Page 10 done, total 83 weibos
# Page 15 done, total 128 weibos
# Page 20 done, total 175 weibos
# Page 25 done, total 221 weibos
# Page 30 done, total 266 weibos
# Page 35 done, total 306 weibos
# Page 40 done, total 352 weibos
# Page 45 done, total 399 weibos
# Page 50 done, total 446 weibos
# Page 55 done, total 493 weibos
# Page 60 done, total 540 weibos
# Page 65 done, total 586 weibos
# Page 70 done, total 635 weibos
# Page 75 done, total 680 weibos
# Page 80 done, total 727 weibos
# Page 85 done, total 770 weibos
# Page 90 done, total 813 weibos
# Page 95 done, total 859 weibos
# Page 100 done, total 899 weibos
# Page 105 done, total 928 weibos
# Page 110 done, total 937 weibos
# Page 115 done, total 937 weibos
# Page 120 done, total 937 weibos
# Page 125 done, total 937 weibos
# Page 130 done, total 937 weibos
# Page 135 done, total 937 weibos
# Page 140 done, total 937 weibos
# Page 145 done, total 937 weibos
# Page 150 done, total 937 weibos
# Page 155 done, total 937 weibos
# Page 160 done, total 937 weibos
# Page 165 done, total 937 weibos
# Page 170 done, total 937 weibos
# Page 175 done, total 937 weibos
# Page 180 done, total 937 weibos
# Page 185 done, total 937 weibos
# Page 190 done, total 937 weibos
# Page 195 done, total 937 weibos
# Page 200 done, total 937 weibos
# Page 205 done, total 937 weibos
# Page 210 done, total 937 weibos
# Page 215 done, total 937 weibos
# Page 220 done, total 937 weibos
# Page 225 done, total 937 weibos
# Page 230 done, total 937 weibos
# Page 235 done, total 937 weibos
# Page 240 done, total 937 weibos
# Page 245 done, total 937 weibos
# Page 250 done, total 937 weibos
# Page 255 done, total 937 weibos
# Page 260 done, total 937 weibos
# Page 265 done, total 937 weibos
# Page 270 done, total 937 weibos
# Page 275 done, total 937 weibos
# Page 280 done, total 937 weibos
# Page 285 done, total 937 weibos
# Page 290 done, total 937 weibos
# Page 295 done, total 937 weibos
# Page 300 done, total 937 weibos
# Page 305 done, total 937 weibos
# Page 310 done, total 937 weibos
# Page 315 done, total 937 weibos
# Page 320 done, total 937 weibos
# Page 325 done, total 937 weibos
# Page 330 done, total 937 weibos
# Page 335 done, total 937 weibos
# Page 340 done, total 937 weibos
# Page 345 done, total 937 weibos
# Page 350 done, total 937 weibos
# Page 355 done, total 937 weibos
# Page 360 done, total 937 weibos
# Page 365 done, total 937 weibos
# Page 370 done, total 937 weibos
# Page 375 done, total 937 weibos
# Page 380 done, total 937 weibos
# Page 385 done, total 937 weibos
# Page 390 done, total 937 weibos
# Page 395 done, total 937 weibos

# %%
json_data = get_page(2)

# %%
results = parse_page(*json_data)
for result in results:
    print(result)
# Out:
# {'id': '4401120409728409', 'created_at': '07-28', 'text': '比昨天还低myz能不能别打了，等我读完再打行不', 'attitudes': 0, 'comments': 0, 'reposts': 0}
# {'id': '4401082136404278', 'created_at': '07-28', 'text': 'myz？', 'attitudes': 0, 'comments': 0, 'reposts': 0, 'origin_text': '一个死也要保持狮子的姿态，一个拼死也要让狮子见证弱者的力量。一场悲剧，两个英雄。happy热哥的秒拍视频', 'origin_user': '鲁国平先生', 'origin_created_at': '08-02'}
# {'id': '4401040805746023', 'created_at': '07-28', 'text': '想哭想要抱抱想喝酒 要跟我的myz一起喝醉一次 还有十几天\n其实这个夏天想过那种自己在家一天只吃一个西瓜的日子 减肥还省事 一个人住多爽啊 但是是跟我妈一起生活的假期 我被喂的好肥。。。嗷嗷哭', 'attitudes': 3, 'comments': 0, 'reposts': 0}
# {'id': '4400962250835104', 'created_at': '08-02', 'text': '发表了博文《糟心的市场，何时能飞扬？》周末将至，传出了MYZ的利空消息，显然我大A又被带了下节奏。对那些想要满仓甚至加高杠杆赌利好的资金来说，糟心的一周还是结束了，感觉像是被黑天鹅狠狠撞了一下腰。不过糟心的市场，何时能飞扬？', 'attitudes': 0, 'comments': 0, 'reposts': 0, 'page_title': '糟心的市场，何时能飞扬？', 'page_url': 'http://blog.sina.com.cn/s/blog_6031c28f0102yqmz.html?ref=weibocard&from=1110106030&weiboauthoruid=1613873807&sinainternalbrowser=topnav&share_menu=1&luicode=10000011&lfid=100103type%3D61%26q%3Dmyz%26t%3D0'}
# {'id': '4400941576600792', 'created_at': '08-02', 'text': '糖苑 回答了：李总您好，同样的剧本，【川普发推:对3000亿商品加10%关税】，MYZ全面升级，更加坚定您四季度看空白糖？一，盘面一度崩盘破5250，技术上双顶很大概率，5400为短期高点？后市几无利好，借助周末糖会拉高出货大概率？5450止损分批空01？二，9月即将交割，可以换做1-5正套？逻辑支持怎么说？ ...全文', 'attitudes': 3, 'comments': 0, 'reposts': 0, 'long_text': '糖苑 回答了：李总您好，同样的剧本，【川普发推:对3000亿商品加10%关税】，MYZ全面升级，更加坚定您四季度看空白糖？一，盘面一度崩盘破5250，技术上双顶很大概率，5400为短期高点？后市几无利好，借助周末糖会拉高出货大概率？5450止损分批空01？二，9月即将交割，可以换做1-5正套？逻辑支持怎么说？谢谢http://t.cn/AiYauiAf'}
# {'id': '4400893371462844', 'created_at': '08-02', 'text': '黑人、HK、MYZ、经济下行，大家的民族情节、爱国情结、生存压力，在么短的时间内都迅速提升，gov也是厉害，好好的一手牌打的稀里哗啦，还把大家骗得晕头转向，本来岁月静好就不容易了，现在敲锣打鼓干大事，以为明天就能成，却全然忘了现在的饿肚子。该讲物质文明的时候，拿精神文明来做挡箭牌，精神文 ...全文', 'attitudes': 0, 'comments': 0, 'reposts': 0, 'long_text': '黑人、HK、MYZ、经济下行，大家的民族情节、爱国情结、生存压力，在么短的时间内都迅速提升，gov也是厉害，好好的一手牌打的稀里哗啦，还把大家骗得晕头转向，本来岁月静好就不容易了，现在敲锣打鼓干大事，以为明天就能成，却全然忘了现在的饿肚子。该讲物质文明的时候，拿精神文明来做挡箭牌，精神文明弄得差不多了，常识也没了。生活不易啊，现在可好了，于事无补的口号喊着，垃圾扔不对地方只能谩骂垃圾污染环境了，精神食粮够够的了还缺钙铁锌硒吗，画大饼冲大饥，这套路忽悠，啧啧啧。居庙堂之高的人都门儿清、鬼精，一再刺激底线，也是大家都能忍。哪些行为示范，文为世德，为后世百年构想的领导人没几个。'}
# {'id': '4400886438922587', 'created_at': '08-02', 'text': '这基本上是myz的结局了吧？//@法兰西微语:美帝不是一个人、没有举国体制，各有各的利益，老川不可能为所欲为 //@阳光帽合V: 你们难道就没想过米帝只要敢大赌一把玩儿命持续加税产业链会转移重组？//@飞翔的海盗旗啊:转发微博', 'attitudes': 0, 'comments': 0, 'reposts': 0, 'origin_text': '路透社：特朗普对中国商品加税， 买单的是美国进口商而非中国。\n- 如此，皆大欢喜，老川间接征到税有钱用，中国也没有受损', 'origin_user': '法兰西微语', 'origin_created_at': '08-02'}
# {'id': '4400873579043822', 'created_at': '08-02', 'text': '#股票# #股票测评# @微博会员\n早评老妖才说到\n近期MYZ提升的背景下\n关注的题材和方向\n要小而精\n今日涨势靠前的个股便验证了方向\n涨幅榜靠前的\n不无是老妖提及到的板块儿\n现在为老妖复盘时间，手里有个股需要解惑的朋友，\n可以私信于老妖 我将细细为你道来：\n万向德隆\n北京君正\n九鼎新材\n北矿科技\n...全文', 'attitudes': 1, 'comments': 0, 'reposts': 0, 'page_title': '北京君正', 'page_url': 'https://m.weibo.cn/p/index?containerid=231500sz300223&luicode=10000011&lfid=100103type%3D61%26q%3Dmyz%26t%3D0', 'long_text': '#股票# #股票测评# @微博会员 早评老妖才说到 近期MYZ提升的背景下 关注的题材和方向 要小而精 今日涨势靠前的个股便验证了方向 涨幅榜靠前的 不无是老妖提及到的板块儿 现在为老妖复盘时间，手里有个股需要解惑的朋友， 可以私信于老妖 我将细细为你道来： 万向德隆 北京君正 九鼎新材 北矿科技 宁波韵升 北方稀土 中钢天源 有研新材 中间科技 鲁信创投 申通快递 数字政通 纳川股份 潜能恒信 卓胜微 财通证券 康跃科技 东华测试 通达股份'}
# {'id': '4400865802262653', 'created_at': '08-02', 'text': '不打上甘岒，抗美援朝能停战吗？MYZ不也一样吗，一付不想打的样子能换来停战吗//@扬韬:敢打，首先得想打。我看到有很多人，不想打仗，梦想完全通过和平手段实现所有目标。', 'attitudes': 4, 'comments': 3, 'reposts': 1, 'origin_text': '林彪说打仗，千条万条，敢打是第一条！', 'origin_user': '但斌', 'origin_created_at': '08-02'}

# %%
# Out:
# 2

# %%
json_data[0].get('data').get('cards')[0].get('card_group')[1].get('mblog')#.get('longText').get('longTextContent')
# Out:
# {'created_at': '昨天 06:00',
#  'id': '4401082136404278',
#  'idstr': '4401082136404278',
#  'mid': '4401082136404278',
#  'can_edit': False,
#  'show_additional_indication': 0,
#  'text': 'myz？',
#  'source': '三星android智能手机',
#  'favorited': False,
#  'pic_types': '',
#  'is_paid': False,
#  'mblog_vip_type': 0,
#  'user': {'id': 6801732679,
#   'screen_name': '记忆不同',
#   'profile_image_url': 'https://tvax1.sinaimg.cn/crop.56.130.326.326.180/007qjnnNly8fwo6irequzj30c80gbdks.jpg?Expires=1564910984&ssig=cVbyg%2Bw1Z8&KID=imgbed,tva',
#   'profile_url': 'https://m.weibo.cn/u/6801732679?uid=6801732679&luicode=10000011&lfid=100103type%3D61%26q%3Dmyz%26t%3D0',
#   'statuses_count': 441,
#   'verified': False,
#   'verified_type': -1,
#   'close_blue_v': False,
#   'description': '',
#   'gender': 'm',
#   'mbtype': 0,
#   'urank': 9,
#   'mbrank': 0,
#   'follow_me': False,
#   'following': False,
#   'followers_count': 577,
#   'follow_count': 2492,
#   'cover_image_phone': 'https://tva1.sinaimg.cn/crop.0.0.640.640.640/549d0121tw1egm1kjly3jj20hs0hsq4f.jpg',
#   'avatar_hd': 'https://wx1.sinaimg.cn/orj480/007qjnnNly8fwo6irequzj30c80gbdks.jpg',
#   'like': False,
#   'like_me': False,
#   'badge': {'user_name_certificate': 1, 'hongrenjie_2019': 1}},
#  'retweeted_status': {'created_at': '08-02',
#   'id': '4400761486120479',
#   'idstr': '4400761486120479',
#   'mid': '4400761486120479',
#   'can_edit': False,
#   'show_additional_indication': 0,
#   'text': '一个死也要保持狮子的姿态，一个拼死也要让狮子见证弱者的力量。一场悲剧，两个英雄。<a data-url="http://t.cn/EUYgQGw" href="https://m.weibo.cn/p/index?containerid=2304444317578047468672&url_type=39&object_type=video&pos=1&luicode=10000011&lfid=100103type%3D61%26q%3Dmyz%26t%3D0" data-hide=""><span class=\'url-icon\'><img style=\'width: 1rem;height: 1rem\' src=\'https://h5.sinaimg.cn/upload/2015/09/25/3/timeline_card_small_video_default.png\'></span><span class="surl-text">happy热哥的秒拍视频</span></a> ',
#   'textLength': 99,
#   'source': '微博 weibo.com',
#   'favorited': False,
#   'pic_types': '',
#   'is_paid': False,
#   'mblog_vip_type': 0,
#   'user': {'id': 1142648704,
#    'screen_name': '鲁国平先生',
#    'profile_image_url': 'https://tvax2.sinaimg.cn/crop.0.0.1080.1080.180/441b6f80ly8g0d06igbjrj20u00u0acm.jpg?Expires=1564910984&ssig=JcLAfLBmuR&KID=imgbed,tva',
#    'profile_url': 'https://m.weibo.cn/u/1142648704?uid=1142648704&luicode=10000011&lfid=100103type%3D61%26q%3Dmyz%26t%3D0',
#    'statuses_count': 74911,
#    'verified': True,
#    'verified_type': 0,
#    'verified_type_ext': 1,
#    'verified_reason': '专栏作家，媒体人，新浪名博，微博区域专家团专家',
#    'close_blue_v': False,
#    'description': '微信公号：ksaaa112111122 QQ：2482689003（新）感谢网易送这款拥有行业领先的电子传真、超大网盘的作家纪念版网易VIP邮箱：luguoping@vip.126.com',
#    'gender': 'm',
#    'mbtype': 12,
#    'urank': 48,
#    'mbrank': 7,
#    'follow_me': False,
#    'following': False,
#    'followers_count': 795224,
#    'follow_count': 2826,
#    'cover_image_phone': 'https://tva1.sinaimg.cn/crop.0.0.640.640.640/549d0121tw1egm1kjly3jj20hs0hsq4f.jpg',
#    'avatar_hd': 'https://wx2.sinaimg.cn/orj480/441b6f80ly8g0d06igbjrj20u00u0acm.jpg',
#    'like': False,
#    'like_me': False,
#    'badge': {'bind_taobao': 1,
#     'dailv': 1,
#     'self_media': 1,
#     'dzwbqlx_2016': 1,
#     'follow_whitelist_video': 1,
#     'panda': 1,
#     'user_name_certificate': 1,
#     'wenchuan_10th': 1,
#     'worldcup_2018': 34,
#     'dailv_2018': 1,
#     'national_day_2018': 1,
#     'relation_display': 1,
#     'memorial_2018': 1,
#     'status_visible': 1,
#     'fu_2019': 1,
#     'suishoupai_2019': 6,
#     'wusi_2019': 1,
#     'hongrenjie_2019': 1}},
#   'reposts_count': 804,
#   'comments_count': 759,
#   'attitudes_count': 2327,
#   'pending_approval_count': 0,
#   'isLongText': False,
#   'reward_exhibition_type': 0,
#   'hide_flag': 0,
#   'visible': {'type': 0, 'list_id': 0},
#   'mblogtype': 0,
#   'more_info_type': 0,
#   'cardid': 'star_004',
#   'number_display_strategy': {'apply_scenario_flag': 3,
#    'display_text_min_number': 1000000,
#    'display_text': '100万+'},
#   'content_auth': 0,
#   'pic_num': 0,
#   'status': 0,
#   'weibo_position': 2,
#   'show_attitude_bar': 0,
#   'page_info': {'page_pic': {'url': 'https://wx4.sinaimg.cn/orj480/659daeadly1fy7o3xwkjvj21120kuwg9.jpg'},
#    'page_url': 'https://m.weibo.cn/p/index?containerid=2304444317578047468672&url_type=39&object_type=video&pos=2&luicode=10000011&lfid=100103type%3D61%26q%3Dmyz%26t%3D0',
#    'page_title': 'happy热哥的秒拍视频',
#    'content1': 'happy热哥的秒拍视频',
#    'content2': '雄狮与野牛厮杀，可以堪称自然界的好莱坞大片，为了生存，雄狮拼到最后一刻，伤痕累累，奄奄一息，在弱肉强食的自然界，没有永远的胜利者，想要活下去，你必须拼尽全力！',
#    'type': 'video',
#    'media_info': {'video_orientation': 'horizontal',
#     'name': 'happy热哥的秒拍视频',
#     'stream_url': 'https://f.us.sinaimg.cn/004FYbtBlx07pZzlAkLu01040200QXew0E010.mp4?label=mp4_ld&template=640x360.28.0&Expires=1564910961&ssig=7XMHwt7Hrb&KID=unistore,video',
#     'stream_url_hd': 'http://f.us.sinaimg.cn/004CQdzclx07pZznPbCo01040201hVc50E010.mp4?label=mp4_hd&template=852x480.28.0&Expires=1564910961&ssig=daxXNlDQ5T&KID=unistore,video',
#     'h5_url': 'https://video.weibo.com/show?fid=1034:4317578047468672',
#     'mp4_sd_url': 'http://f.us.sinaimg.cn/004FYbtBlx07pZzlAkLu01040200QXew0E010.mp4?label=mp4_ld&template=640x360.28.0&Expires=1564910961&ssig=7XMHwt7Hrb&KID=unistore,video',
#     'mp4_hd_url': 'http://f.us.sinaimg.cn/004CQdzclx07pZznPbCo01040201hVc50E010.mp4?label=mp4_hd&template=852x480.28.0&Expires=1564910961&ssig=daxXNlDQ5T&KID=unistore,video',
#     'h265_mp4_hd': '',
#     'h265_mp4_ld': '',
#     'inch_4_mp4_hd': '',
#     'inch_5_mp4_hd': '',
#     'inch_5_5_mp4_hd': '',
#     'mp4_720p_mp4': 'http://f.us.sinaimg.cn/000xyImblx07pZzGdQwU01040205OMt40E030.mp4?label=mp4_720p&template=1280x720.20.0&Expires=1564910961&ssig=fMrBQzT1Ke&KID=unistore,video',
#     'hevc_mp4_720p': '',
#     'prefetch_type': 1,
#     'prefetch_size': 495526,
#     'act_status': 1,
#     'protocol': 'general',
#     'media_id': '4317578047468672',
#     'origin_total_bitrate': 2899694,
#     'duration': 463,
#     'next_title': '一个死也要保持狮子的姿态，一个拼死也要让狮子见证弱者的力量。一场悲剧，两个英雄。\u200b',
#     'video_details': [{'size': 11437230,
#       'bitrate': 192,
#       'label': 'hevc_mp4_hd',
#       'prefetch_size': 439333},
#      {'size': 12620752,
#       'bitrate': 212,
#       'label': 'mp4_sd_url',
#       'prefetch_size': 444860},
#      {'size': 19047769,
#       'bitrate': 321,
#       'label': 'mp4_hd_url',
#       'prefetch_size': 495526},
#      {'size': 85984394,
#       'bitrate': 1449,
#       'label': '',
#       'prefetch_size': 991121}],
#     'hevc_mp4_hd': 'http://f.us.sinaimg.cn/002hi5DVgx07tAXzvCnl01041200LZls0E010.mp4?label=hevc_mp4_hd&template=852x480.32.0&Expires=1564910961&ssig=IEvn2jOfF4&KID=unistore,video',
#     'play_completion_actions': [{'type': '1',
#       'icon': 'http://img.t.sinajs.cn/t6/style/images/face/feed_c_r.png',
#       'text': '重播',
#       'link': '',
#       'btn_code': 1000,
#       'show_position': 1,
#       'actionlog': {'oid': '2304444317578047468672',
#        'act_code': 1221,
#        'act_type': 0,
#        'source': 'video'}}],
#     'video_publish_time': 1544874287,
#     'play_loop_type': 0,
#     'titles': [{'default': True, 'title': '，，，，，，，，，'}],
#     'author_mid': '4317578463292295',
#     'author_name': 'happy热哥',
#     'playlist_id': 4300956322731194,
#     'is_playlist': 1,
#     'get_playlist_id': 4300956322731194,
#     'is_contribution': 1,
#     'extra_info': {'sceneid': 'feed'},
#     'has_recommend_video': 1,
#     'back_paster_info': {'has_back_paster': 1,
#      'request_param': {'video_type': 1, 'video_orientation': 'horizontal'}},
#     'author_verified_type': 0,
#     'video_download_strategy': {'abandon_download': 0},
#     'banner': {'url': 'https://h5.sinaimg.cn/upload/1000/48/2019/08/01/hongrenjie.jpeg',
#      'scheme': 'sinaweibo://searchall?containerid=231522&q=%23%E7%94%B5%E5%BD%B1%E7%BA%A2%E4%BA%BAshow%23',
#      'link': 'sinaweibo://searchall?containerid=231522&q=%23%E7%94%B5%E5%BD%B1%E7%BA%A2%E4%BA%BAshow%23',
#      'app_scheme': 'sinaweibo://searchall?containerid=231522&q=%23%E7%94%B5%E5%BD%B1%E7%BA%A2%E4%BA%BAshow%23',
#      'actionlog': {'oid': '1034:4317578047468672', 'act_code': 3602}},
#     'online_users': '176万次观看',
#     'online_users_number': 1762322,
#     'ttl': 3600,
#     'storage_type': 'oss',
#     'is_keep_current_mblog': 0},
#    'play_count': 1762322,
#    'object_id': '1034:4317578047468672'},
#   'retweeted': 1,
#   'bid': 'I0jOcpGdp'},
#  'reposts_count': 0,
#  'comments_count': 0,
#  'attitudes_count': 0,
#  'pending_approval_count': 0,
#  'isLongText': False,
#  'reward_exhibition_type': 0,
#  'hide_flag': 0,
#  'visible': {'type': 0, 'list_id': 0},
#  'mblogtype': 0,
#  'rid': '1_0_0_3068983458511371952_0_0_0',
#  'more_info_type': 0,
#  'extern_safe': 0,
#  'number_display_strategy': {'apply_scenario_flag': 3,
#   'display_text_min_number': 1000000,
#   'display_text': '100万+'},
#  'content_auth': 0,
#  'pic_num': 0,
#  'status': 0,
#  'digit_attr': '92',
#  'dispatch_ctrl': '0',
#  'kwfilter_pass': '0',
#  'extra_info': {'ID': '4401082136404278',
#   'cont_sign': '919019053',
#   'digit_attr': '92',
#   'dispatch_ctrl': '0',
#   'dup': '3977562236448485',
#   'dup1': '2944741',
#   'dup2': '59270297',
#   'dup_cont': '3194652723',
#   'hit_score': '0',
#   'kwfilter_pass': '0',
#   'simhash2': '4104465764',
#   'simhash_dup': '17628546227126306867',
#   'vote': '0'},
#  'itemid': 'seqid:1993179106|type:61|t:0|pos:2-0-1|q:myz|ext:&cate=31&mid=4401082136404278&qri=0&qtime=1564907384&',
#  'analysis_extra': 'seqid:1993179106|type:61|t:0|pos:2-0-1|q:myz|ext:&cate=31&mid=4401082136404278&qri=0&qtime=1564907384&',
#  'weibo_position': 3,
#  'show_attitude_bar': 0,
#  'obj_ext': '176万次观看',
#  'raw_text': 'myz？',
#  'bid': 'I0s9nqS2O'}

# %%
page
# Out:
# 294
